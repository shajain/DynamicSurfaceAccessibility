# %% [markdown]
# # Read `report.parquet`
#
# Install the package once from the project root (with your environment activated):
#
# `pip install -e ".[dev]"`
#
# Then select a Jupyter kernel that uses that environment.

# %%
from dsa import default_parquet_path, read_report_parquet

default_parquet_path()

# %%
df = read_report_parquet()
df.shape

# %%
df.head()

# %%
df.dtypes
